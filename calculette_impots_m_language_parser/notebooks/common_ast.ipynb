# %%
import http.client
import re
import json

# %% [markdown]
# ## Get a simplified list of input variables

# %%
conn = http.client.HTTPConnection("www3.finances.gouv.fr")
conn.request("GET", "/calcul_impot/2015/simplifie/calc_s_data.htm")
response = conn.getresponse()

# %%
print(response.status, response.reason)
# Out:
# 200 OK

# %%
data = response.read()
data = data.decode(encoding='utf-8')

# %%
re.findall('<B>(.*)</B>', data)
# Out:
# ['<SPAN class="titre"><SPAN class="txtWhite">&nbsp;Vous &ecirc;tes :</SPAN></SPAN>',
#  '&nbsp;&nbsp;X&nbsp;&nbsp;',
#  'M',
#  '&nbsp;&nbsp;X&nbsp;&nbsp;',
#  'O',
#  'B',
#  'C',
#  '&nbsp;&nbsp;Y&nbsp;&nbsp;',
#  'D',
#  '&nbsp;&nbsp;Z&nbsp;&nbsp;',
#  'V',
#  '<SPAN class="titre"><SPAN class="txtWhite">&nbsp;Parent isol&eacute;</SPAN></SPAN>',
#  '<FONT size="-1">T</FONT>',
#  '<SPAN class="titre"><SPAN class="txtWhite">Attribution d\'une demi-part suppl&eacute;mentaire</SPAN></SPAN>',
#  '1. En cas de c&eacute;libat, divorce, s&eacute;paration, veuvage',
#  '<FONT size="-1">L</FONT>',
#  '<FONT size="-1">N</FONT>',
#  "2. Titulaire d'une pension (militaire, accident du travail) pour une invalidit&eacute; d'au moins 40 % ou d'une carte d'invalidit&eacute; d'au moins 80&nbsp;%",
#  '<FONT size="-1">P</FONT>',
#  '<FONT size="-1">F</FONT>',
#  "3. Titulaire de la carte du combattant ou d'une pension militaire d'invalidit&eacute; ou de victime de guerre ",
#  '&middot; ',
#  '&middot; ',
#  '&middot; ',
#  '<FONT size="-1">W</FONT>',
#  '<FONT size="-1">S</FONT>',
#  '<FONT size="-1">G</FONT>',
#  ' <FONT size="-1">F</FONT>',
#  '<FONT size="-1">G</FONT>',
#  '<FONT size="-1">H</FONT>',
#  '<FONT size="-1">I</FONT>',
#  '<FONT size="-1">R</FONT>',
#  '<FONT size="-1">J</FONT>',
#  '<FONT size="-1">N</FONT>',
#  'D&eacute;clarant 1',
#  'D&eacute;clarant 2',
#  "&nbsp;Indiquez vos seuls revenus d'activit&eacute;",
#  '1AJ',
#  '1BJ',
#  '1CJ',
#  '1DJ',
#  '&nbsp;Indiquez vos autres revenus imposables',
#  '1AP',
#  '1BP',
#  '1CP',
#  '1DP',
#  '&nbsp;Indiquez vos frais r&eacute;els',
#  '1AK',
#  '1BK',
#  '1CK',
#  '1DK',
#  "&nbsp;Demandeur d'emploi inscrit depuis plus d'un an",
#  '1AI',
#  '1BI',
#  '1CI',
#  '1DI',
#  '<SPAN class="titre"><SPAN class="txtWhite">PRIME POUR L\'EMPLOI</SPAN></SPAN>',
#  '&nbsp;&nbsp;1AX',
#  '&nbsp;&nbsp;1AV',
#  '&nbsp;&nbsp;1BX',
#  '&nbsp;&nbsp;1BV',
#  '&nbsp;&nbsp;1CX',
#  '&nbsp;&nbsp;1CV',
#  '&nbsp;&nbsp;1DX',
#  '&nbsp;&nbsp;1DV',
#  '1BL',
#  '1CB',
#  '1DQ',
#  '&nbsp;Pensions de retraite et rentes',
#  '1AS',
#  '1BS',
#  '1CS',
#  '1DS',
#  '&nbsp;Pensions de retraite en capital taxables &agrave; 7,5%',
#  '1AT',
#  '1BT',
#  "&nbsp;Pensions d'invalidit&eacute; ",
#  '1AZ',
#  '1BZ',
#  '1CZ',
#  '1DZ',
#  '&nbsp;Pensions alimentaires per&ccedil;ues ',
#  '1AO',
#  '1BO',
#  '1CO',
#  '1DO',
#  '1AW',
#  '1BW',
#  '1CW',
#  '1DW',
#  '2DH',
#  '2EE',
#  '2DC',
#  '2FU',
#  '2CH',
#  '2TS',
#  '2GO',
#  '2TR',
#  '2FA',
#  '2CG',
#  '2BH',
#  '2CA',
#  '2AB',
#  '2CK',
#  '2BG',
#  '2LA',
#  '2LB',
#  '2AA',
#  '2AL',
#  '2AM',
#  '2AN',
#  '2AQ',
#  '2AR',
#  '2DM',
#  'Gains de cessions de valeurs mobili&egrave;res, de droits sociaux et gains assimil&eacute;s',
#  '3VG',
#  '3VH',
#  '3SG',
#  '3SH',
#  'Micro foncier',
#  '4BE',
#  '4BA',
#  '4BB',
#  '4BC',
#  '4BD',
#  '4BF',
#  '0XX',
#  '6DE',
#  '6GI',
#  '6GJ',
#  '6EL',
#  '6EM',
#  '6GP',
#  '6GU',
#  '6DD',
#  '&nbsp;Epargne retraite PERP ET PRODUITS ASSIMIL&Eacute;S ( PREFON, COREM et  C.G.O.S )',
#  '6RS',
#  '6SS',
#  '6RT',
#  '6ST',
#  '6RU',
#  '6SU',
#  '6PS',
#  '6PS',
#  '6PT',
#  '6PT',
#  '6PU',
#  '6PU',
#  '6PS',
#  '6PS',
#  '6PT',
#  '6PT',
#  '6PU',
#  '6PU',
#  '6QR',
#  '6QW',
#  'Vos dons &agrave; des organismes &eacute;tablis en France',
#  '7UD',
#  '7UF',
#  '7UH',
#  '7XS',
#  '7XT',
#  '7XU',
#  '7XW',
#  '7XY',
#  "Vos dons &agrave; des organismes d'int&eacute;r&ecirc;t g&eacute;n&eacute;ral &eacute;tablis dans un &eacute;tat europ&eacute;en",
#  '7VA',
#  '7VC',
#  'Vos cotisations syndicales des salari&eacute;s et pensionn&eacute;s',
#  '7AC',
#  '7AE',
#  '7AG',
#  "Vos autres charges ouvrant droit &agrave; r&eacute;duction d'imp&ocirc;t ou &agrave; cr&eacute;dit d'imp&ocirc;t",
#  "Sommes vers&eacute;es pour l'emploi d'un salari&eacute; &agrave; domicile",
#  '7DB',
#  '7DF',
#  '7DD',
#  '7DL',
#  '7DQ',
#  '7DG',
#  '7VZ',
#  '7VV',
#  '7VU',
#  '7VT',
#  '7VX',
#  "D&eacute;penses d'accueil dans un &eacute;tablissement pour personnes  d&eacute;pendantes&nbsp;",
#  '7CD',
#  '7CE',
#  '7GA',
#  '7GE',
#  '7GB',
#  '7GF',
#  '7GC',
#  '7GG',
#  "Enfants  poursuivant leurs &eacute;tudes, indiquez le nombre d'enfants concern&eacute;s (niveau d'&eacute;tudes au 31 d&eacute;cembre 2014) &nbsp;",
#  '7EA',
#  '&nbsp;',
#  '7EB',
#  '7EC',
#  '&nbsp;',
#  '7ED',
#  '7EF',
#  '&nbsp;',
#  '7EG',
#  '7GZ',
#  'Int&eacute;r&ecirc;ts des pr&ecirc;ts &eacute;tudiants (contrats conclus entre le 1-09-2005 et le 31-12-2008)',
#  '7UK',
#  '7VO',
#  '7TD',
#  'Vos prestations compensatoires',
#  '7WN',
#  '7WO',
#  '7WM',
#  '7WP',
#  "D&eacute;penses en faveur de la qualit&eacute; environnementale de l'habitation principale",
#  '7WE',
#  '7WG',
#  '7SD',
#  '7SA',
#  '7SE',
#  '7SB',
#  '7SF',
#  '7SC',
#  '7WC',
#  '7WB',
#  '7SG',
#  '7RG',
#  '7VG',
#  '7VH',
#  '7SH',
#  '7RH',
#  '7SI',
#  '7RI',
#  '7WT',
#  '7WU',
#  '7SJ',
#  '7RJ',
#  '7SK',
#  '7RK',
#  '7SL',
#  '7RL',
#  '7SN',
#  '7RN',
#  '7SP',
#  '7RP',
#  '7SR',
#  '7RR',
#  '7SS',
#  '7RS',
#  '7SQ',
#  '7RQ',
#  '7ST',
#  '7RT',
#  '7SV',
#  '7TV',
#  '7SW',
#  '7TW',
#  '7RV',
#  '7RW',
#  '7RZ',
#  "D&eacute;penses en faveur de l'aide aux personnes",
#  '7WJ',
#  '7WL',
#  '<SPAN class="titre"><SPAN class="txtWhite">AUTRES IMPUTATIONS, REPRISES DE R&Eacute;DUCTIONS D\'IMP&Ocirc;T, CONVENTIONS INTERNATIONALES, DIVERS</SPAN></SPAN>',
#  '8BY',
#  '8CY',
#  '8UT',
#  '8TF',
#  '8TI',
#  '8TK']

# %%
alias_simple = ['M', 'O', 'B', 'C', 'D', 'V', 'T', 'L',
 'N', 'P', 'F', 'W', 'S', 'G', 'F', 'G',
 'H', 'I', 'R', 'J', 'N', '1AJ', '1BJ', '1CJ',
 '1DJ', '1AP', '1BP', '1CP', '1DP', '1AK', '1BK', '1CK',
 '1DK', '1AI', '1BI', '1CI', '1DI', '1AX', '1AV', '1BX',
 '1BV', '1CX', '1CV', '1DX', '1DV', '1BL', '1CB', '1DQ',
 '1AS', '1BS', '1CS', '1DS', '1AT', '1BT', '1AZ', '1BZ',
 '1CZ', '1DZ', '1AO', '1BO', '1CO', '1DO', '1AW', '1BW',
 '1CW', '1DW', '2DH', '2EE', '2DC', '2FU', '2CH', '2TS',
 '2GO', '2TR', '2FA', '2CG', '2BH', '2CA', '2AB', '2CK',
 '2BG', '2LA', '2LB', '2AA', '2AL', '2AM', '2AN', '2AQ',
 '2AR', '2DM', '3VG', '3VH', '3SG', '3SH', '4BE', '4BA',
 '4BB', '4BC', '4BD', '4BF', '0XX', '6DE', '6GI', '6GJ',
 '6EL', '6EM', '6GP', '6GU', '6DD', '6RS', '6SS', '6RT',
 '6ST', '6RU', '6SU', '6PS', '6PS', '6PT', '6PT', '6PU',
 '6PU', '6PS', '6PS', '6PT', '6PT', '6PU', '6PU', '6QR',
 '6QW', '7UD', '7UF', '7UH', '7XS', '7XT', '7XU', '7XW',
 '7XY', '7VA', '7VC', '7AC', '7AE', '7AG', '7DB', '7DF',
 '7DD', '7DL', '7DQ', '7DG', '7VZ', '7VV', '7VU', '7VT',
 '7VX', '7CD', '7CE', '7GA', '7GE', '7GB', '7GF', '7GC',
 '7GG', '7EA', '7EB', '7EC', '7ED', '7EF', '7EG', '7GZ',
 '7UK', '7VO', '7TD', '7WN', '7WO', '7WM', '7WP', '7WE',
 '7WG', '7SD', '7SA', '7SE', '7SB', '7SF', '7SC', '7WC',
 '7WB', '7SG', '7RG', '7VG', '7VH', '7SH', '7RH', '7SI',
 '7RI', '7WT', '7WU', '7SJ', '7RJ', '7SK', '7RK', '7SL',
 '7RL', '7SN', '7RN', '7SP', '7RP', '7SR', '7RR', '7SS',
 '7RS', '7SQ', '7RQ', '7ST', '7RT', '7SV', '7TV', '7SW',
 '7TW', '7RV', '7RW', '7RZ', '7WJ', '7WL', '8BY', '8CY',
 '8UT', '8TF', '8TI', '8TK']

# %%
for v in ['0AC', '0AM', '0AD', '0AV',
'0AO', '0CF', '1AJ', '1AP',
'1AS', '1BJ', '1BP', '1BS',
'2DC', '2TR', '2CK', '6DE',
'7UF']:
    if v not in alias_simple:
        print(v)
# Out:
# 0AC
# 0AM
# 0AD
# 0AV
# 0AO
# 0CF

# %%
alias_simple += ['0AC', '0AM', '0AD', '0AV', '0AO', '0CF']

# %%
len(alias_simple)
# Out:
# 234

# %% [markdown]
# ## Precompute graph for other variables

# %%
import math

def product(l):
    accu = 1.
    for e in l:
        accu *= e
    return accu

def boolean_or(l):
    for e in l:
        if e:
            return 1.
    return 0.

def boolean_et(l):
    for e in l:
        if not l:
            return 0.
    return 1.


functions_mapping = {
    '+': sum,
    'sum': sum,
    '*': product,
    'product': product,
    '-': (lambda x: -x[0]),
    'negate': (lambda x: -x[0]),
    'unary:-': (lambda x: -x[0]),
    'positif': (lambda x: float(x[0]>0)),
    'positif_ou_nul': (lambda x: float(x[0]>=0)),
    'null': (lambda x: float(x[0]==0)),
    'operator:>=': (lambda x: float(x[0]>=x[1])),
    'operator:<=': (lambda x: float(x[0]<=x[1])),
    'operator:>': (lambda x: float(x[0]>x[1])),
    'operator:<': (lambda x: float(x[0]<x[1])),
    'operator:=': (lambda x: float(x[0]==x[1])),
    'ternary': (lambda x: x[1] if x[0] else x[2]),
    'si': (lambda x: x[1] if x[0] else 0.),
    'inverse': (lambda x: 1/x[0] if x[0] else 0.),
    'invert': (lambda x: 1/x[0] if x[0] else 0.),
    'max': max,
    'min': min,
    'inf': (lambda x: float(math.floor(x[0]))),
    'arr': (lambda x: float(round(x[0]))),
    'abs': (lambda x: abs(x[0])),
    'present': (lambda x: float(x[0] != 0.)),
    'boolean:ou': boolean_or,
    'boolean:et': boolean_et,
    'dans': (lambda x: 1. if (x[0] in x[1:]) else 0.)
}

# %%
with open('../../json/light_ast/computing_order.json', 'r') as f:
    computing_order = json.load(f)

with open('../../json/light_ast/formulas_light.json', 'r') as f:
    formulas_light = json.load(f)

with open('../../json/light_ast/constants_light.json', 'r') as f:
    constants_light = json.load(f)

with open('../../json/light_ast/inputs_light.json', 'r') as f:
    inputs_light = json.load(f)

with open('../../json/light_ast/unknowns_light.json', 'r') as f:
    unknowns_light = json.load(f)

with open('../../json/simplified_ast/input_variables.json', 'r') as f:
    input_variables = json.load(f)

# %%
alias2name = {i['alias']: i['name'] for i in input_variables}

# %%
inputs_simple = []
for alias in alias_simple:
    if alias in alias2name:
        inputs_simple.append(alias2name[alias])
    else:
        print('Alias %s not found.'%alias)
# Out:
# Alias M not found.
# Alias O not found.
# Alias B not found.
# Alias C not found.
# Alias D not found.
# Alias V not found.
# Alias T not found.
# Alias L not found.
# Alias N not found.
# Alias P not found.
# Alias F not found.
# Alias W not found.
# Alias S not found.
# Alias G not found.
# Alias F not found.
# Alias G not found.
# Alias H not found.
# Alias I not found.
# Alias R not found.
# Alias J not found.
# Alias N not found.

# %%
def compute_formula(node):
    nodetype = node['nodetype']

    if nodetype == 'symbol':
        name = node['name']
        if name in formulas_simple:
            return node

        if name in useless_simple:
            return useless_simple[name]

        if name in inputs_light:
            if name in inputs_simple:
                return node
            return {'nodetype': 'float', 'value': 0.}

        if name in unknowns_light:
            return {'nodetype': 'float', 'value': 0.}

        raise Exception('Unknown variable category for %s.'%name)

    if nodetype == 'float':
        return node

    if nodetype == 'call':
        name = node['name']
        args = [compute_formula(child) for child in node['args']]
        return {'nodetype': 'call', 'name': name, 'args': args}

    raise ValueError('Unknown type : %s'%nodetype)

# %%
formulas_simple = {}
computing_order_simple = []
useless_simple = {
    k: {'nodetype': 'float', 'value': v}
    for k, v in constants_light.items()
}

for variable in computing_order:
    formula = formulas_light[variable]
    result = compute_formula(formula)
    nodetype = result['nodetype']
    if nodetype == 'call':
        formulas_simple[variable] = result
        computing_order_simple.append(variable)
    else:
        print('Useless variable : %s.'%variable)
        useless_simple[variable] = result
# Out:
# Useless variable : REB.
# Useless variable : 1RNC.
# Useless variable : 2RNC.
# Useless variable : 1RIA.
# Useless variable : 2RIA.
# Useless variable : SPEBASABP.
# Useless variable : SPEBASABC.
# Useless variable : SPEBASABV.
# Useless variable : RRFTEO.
# Useless variable : TSB4.
# Useless variable : TSB1.
# Useless variable : TSB3.
# Useless variable : TSB2.
# Useless variable : TS4.
# Useless variable : PRC.
# Useless variable : TS3.
# Useless variable : PRV.
# Useless variable : TS1.
# Useless variable : TS2.
# Useless variable : REVRVO.
# Useless variable : TTSB1.
# Useless variable : TTSB4.
# Useless variable : TTSB3.
# Useless variable : TTSB2.
# Useless variable : TTS1.
# Useless variable : TTS4.
# Useless variable : TTS2.
# Useless variable : TTS3.
# Useless variable : PDEDMINC.
# Useless variable : PERPSALDC.
# Useless variable : PDEDMINV.
# Useless variable : PERPSALDV.
# Useless variable : LIMDPAE.
# Useless variable : TSPEBASABP.
# Useless variable : TSPEBASABV.
# Useless variable : TSPEBASABC.
# Useless variable : XDFC.
# Useless variable : XDFV.
# Useless variable : RDRV.
# Useless variable : NB1.
# Useless variable : IPQ01.
# Useless variable : REV4C.
# Useless variable : REV4V.
# Useless variable : IPQ05.
# Useless variable : DCOTFOR.
# Useless variable : DFIPDOM.
# Useless variable : DFORET.
# Useless variable : DFIPC.
# Useless variable : DCELREPGK.
# Useless variable : DCELFD.
# Useless variable : DREDMEUB.
# Useless variable : DREDREP.
# Useless variable : DINVRED.
# Useless variable : DILMPA.
# Useless variable : DILMIY.
# Useless variable : DILMIX.
# Useless variable : DILMPB.
# Useless variable : DILMIH.
# Useless variable : DILMJC.
# Useless variable : DILMJI.
# Useless variable : DILMIZ.
# Useless variable : DILMPC.
# Useless variable : DILMIC.
# Useless variable : DILMJS.
# Useless variable : DILMPD.
# Useless variable : DREPMEU.
# Useless variable : DILMPE.
# Useless variable : DPROREP.
# Useless variable : DMEUBLE.
# Useless variable : DREPNPRO.
# Useless variable : DILMIB.
# Useless variable : DILMIA.
# Useless variable : DILMJW.
# Useless variable : DILMJY.
# Useless variable : DILMJX.
# Useless variable : DILMOD.
# Useless variable : DILMJV.
# Useless variable : DILMOE.
# Useless variable : DILMOB.
# Useless variable : DILMOC.
# Useless variable : DILMOA.
# Useless variable : TTPVQ.
# Useless variable : RPINELTOT.
# Useless variable : RIDOMPROTOT.
# Useless variable : ID16.
# Useless variable : DBAIP.
# Useless variable : TXMOYIMPDEN5.
# Useless variable : CDIS.
# Useless variable : TAXLOY.
# Useless variable : IAMD2.
# Useless variable : IRB.
# Useless variable : BCIGA.
# Useless variable : IAMD1.
# Useless variable : PPE_DEBUT.
# Useless variable : PPE_FIN.
# Useless variable : PPETX3.
# Useless variable : PPETX2.
# Useless variable : PPETX1.
# Useless variable : PPE_RTA4.
# Useless variable : PPE_RTA2.
# Useless variable : PPE_RTA1.
# Useless variable : PPE_RTA3.
# Useless variable : DTEC.
# Useless variable : CRESINTER.
# Useless variable : DLOYIMP.
# Useless variable : ALOYIMP.
# Useless variable : PHAUTREV.
# Useless variable : PTAXLOY.
# Useless variable : PTAXA.
# Useless variable : PPCAP.
# Useless variable : PCDIS.
# Useless variable : PRSE3.
# Useless variable : PCSG.
# Useless variable : PRSE4.
# Useless variable : PREGV.
# Useless variable : PRSE2.
# Useless variable : PRDS.
# Useless variable : PCVN.
# Useless variable : PGLOA.
# Useless variable : PRSE5.
# Useless variable : PRSE1.
# Useless variable : PPRS.
# Useless variable : PTOT.
# Useless variable : IDRT.
# Useless variable : IDRS3.

# %% [markdown]
# ## Some simplifications

# %%
def replace(a, b):
    keys_to_del = list(a)
    for k in keys_to_del:
        del a[k]
    for k in b:
        a[k] = b[k]

# %%
def simplify_formula(node):
    modify = False
    nodetype = node['nodetype']

    if nodetype == 'symbol':
        name = node['name']
        if name in useless_simple:
            replace(node, useless_simple[name])
            return True
        return False

    if nodetype == 'float':
        return False

    if nodetype == 'call':
        name = node['name']

        if name == 'sum':
            if node['args'] == []:
                replace(node, {'nodetype': 'float', 'value': 0.})
                return True

            if len(node['args']) == 1:
                arg = node['args'][0]
                keys_to_del = list(node)
                for k in keys_to_del:
                    del node[k]
                for k in arg:
                    node[k] = arg[k]
                return True

            nargs = len(node['args'])
            node['args'] = [arg for arg in node['args'] if arg != {'nodetype': 'float', 'value': 0.}]
            if nargs != len(node['args']):
                modify = True

        if name == 'product':
            if node['args'] == []:
                replace(node, {'nodetype': 'float', 'value': 1.})
                return True

            if len(node['args']) == 1:
                arg = node['args'][0]
                replace(node, arg)
                return True

            nargs = len(node['args'])
            node['args'] = [arg for arg in node['args'] if arg != {'nodetype': 'float', 'value': 1.}]
            if nargs != len(node['args']):
                modify = True

            for arg in node['args']:
                if arg == {'nodetype': 'float', 'value': 0.}:
                    replace(node, {'nodetype': 'float', 'value': 0.})
                    return True

        for arg in node['args']:
            modify = modify or simplify_formula(arg)

        name = node['name']
        args = node['args']
        nodetypes = [arg['nodetype'] for arg in args]
        if set(nodetypes) == set(['float']):
            values = [arg['value'] for arg in args]
            function = functions_mapping[name]
            value = function(values)
            assert(type(value).__name__ == 'float')
            replace(node, {'nodetype': 'float', 'value': value})
            return True
            
        return modify
            

    raise ValueError('Unknown type : %s'%nodetype)

# %%
modify = True
while modify == True:
    modify = False
    new_computing_order = []
    new_formulas = {}
    for variable in computing_order_simple:
        formula = formulas_simple[variable]
        modify = modify or simplify_formula(formula)
        if formula['nodetype'] == 'call':
            new_computing_order.append(variable)
            new_formulas[variable] = formula
        else:
            print('Useless variable : %s.'%variable)
            useless_simple[variable] = formula
    computing_order_simple = new_computing_order
    formulas_simple = new_formulas
# Out:
# Useless variable : EAC.
# Useless variable : PAC.
# Useless variable : NIN.
# Useless variable : BOOL_0AZ.
# Useless variable : NPS.
# Useless variable : AGC.
# Useless variable : AGV.
# Useless variable : NCC.
# Useless variable : NSA.
# Useless variable : NSP.
# Useless variable : NBQAR4.
# Useless variable : NBQAR1.
# Useless variable : NBQAR3.
# Useless variable : NBQAR2.
# Useless variable : BOOL_0BT.
# Useless variable : NBQART.
# Useless variable : NBQAR.
# Useless variable : ABTMA.
# Useless variable : V_CNR.
# Useless variable : DAR.
# Useless variable : BARSREVP.
# Useless variable : DEFBAHREP.
# Useless variable : 4DEFBAHREP.
# Useless variable : BARSP.
# Useless variable : BAEMP.
# Useless variable : BARAP.
# Useless variable : BARREVAP.
# Useless variable : DEFBACREP.
# Useless variable : 4DEFBACREP.
# Useless variable : BAEP.
# Useless variable : BAQP.
# Useless variable : BARSREVC.
# Useless variable : DEFBAHREC.
# Useless variable : 4DEFBAHREC.
# Useless variable : BARSC.
# Useless variable : BAEMC.
# Useless variable : BARREVAC.
# Useless variable : DEFBACREC.
# Useless variable : 4DEFBACREC.
# Useless variable : BARAC.
# Useless variable : BAEC.
# Useless variable : BAQC.
# Useless variable : BAMC.
# Useless variable : BAFORC.
# Useless variable : BANC.
# Useless variable : BAHQC.
# Useless variable : BAFORV.
# Useless variable : BARSV.
# Useless variable : BARSREVV.
# Useless variable : DEFBAHREV.
# Useless variable : BAMV.
# Useless variable : BARAV.
# Useless variable : BARREVAV.
# Useless variable : DEFBACREV.
# Useless variable : BANV.
# Useless variable : BAHQV.
# Useless variable : BAMP.
# Useless variable : BAFORP.
# Useless variable : BANP.
# Useless variable : BAHQP.
# Useless variable : BAHQT.
# Useless variable : BAHQTOTMIN.
# Useless variable : 4DEFBACREV.
# Useless variable : BAEV.
# Useless variable : 4DEFBAHREV.
# Useless variable : BAEMV.
# Useless variable : BAQV.
# Useless variable : BAQTOTMIN.
# Useless variable : DAGRIIMP.
# Useless variable : TOTDAGRI.
# Useless variable : BAHQTOTMAXP.
# Useless variable : SOMDEFBANI.
# Useless variable : DEFBANIF.
# Useless variable : BANOR.
# Useless variable : RCMNAB.
# Useless variable : 2RCMRABD.
# Useless variable : 2RCMRNABD.
# Useless variable : RCMAB.
# Useless variable : 2RCMRTNC.
# Useless variable : 2RCMRNTNC.
# Useless variable : RTNC.
# Useless variable : RTCAR.
# Useless variable : RAVC.
# Useless variable : 2REGPRIVM.
# Useless variable : RCMPRIVM.
# Useless variable : RCMFRART1731.
# Useless variable : 2ABAVC.
# Useless variable : TABAVC.
# Useless variable : DFRCMN.
# Useless variable : TRCMABD.
# Useless variable : FRAN.
# Useless variable : 2FRAN.
# Useless variable : FRAR.
# Useless variable : 2FRAR.
# Useless variable : 2RAR.
# Useless variable : 7RCM_I.
# Useless variable : 2RAO.
# Useless variable : 2RCAV.
# Useless variable : TRCM.
# Useless variable : FRAU.
# Useless variable : 2FRAU.
# Useless variable : 2RAU.
# Useless variable : 5RCM_I.
# Useless variable : 2RAN.
# Useless variable : 2RCM_I.
# Useless variable : MIB_NETNPCT.
# Useless variable : DEFBICNPF.
# Useless variable : BINTAC.
# Useless variable : MIB_TPRESC.
# Useless variable : MIB_APC.
# Useless variable : MIB_ABPC.
# Useless variable : MIB_ABNPPC.
# Useless variable : MIB_NETNPPC.
# Useless variable : BINHTAC.
# Useless variable : MIB_TVENC.
# Useless variable : MIB_AVC.
# Useless variable : MIB_ABVC.
# Useless variable : MIB_ABNPVC.
# Useless variable : MIB_NETNPVC.
# Useless variable : BICNPC.
# Useless variable : DEFNP.
# Useless variable : MIB_TPRESV.
# Useless variable : MIB_APV.
# Useless variable : MIB_ABPV.
# Useless variable : MIB_ABNPPV.
# Useless variable : MIB_NETNPPV.
# Useless variable : BINTAV.
# Useless variable : BINHTAV.
# Useless variable : MIB_TVENV.
# Useless variable : MIB_AVV.
# Useless variable : MIB_ABVV.
# Useless variable : MIB_ABNPVV.
# Useless variable : MIB_NETNPVV.
# Useless variable : BICNPV.
# Useless variable : MIB_TVENP.
# Useless variable : MIB_AVP.
# Useless variable : MIB_ABVP.
# Useless variable : MIB_ABNPVP.
# Useless variable : MIB_NETNPVP.
# Useless variable : MIB_TPRESP.
# Useless variable : MIB_APP.
# Useless variable : MIB_ABPP.
# Useless variable : MIB_ABNPPP.
# Useless variable : MIB_NETNPPP.
# Useless variable : BINHTAP.
# Useless variable : BINTAP.
# Useless variable : BICNPP.
# Useless variable : DEFNPI.
# Useless variable : BICNPF.
# Useless variable : BIHTAC.
# Useless variable : MIB_NETVC.
# Useless variable : MIB_NETPV.
# Useless variable : MIB_NETPC.
# Useless variable : BIPTAV.
# Useless variable : BIPTAC.
# Useless variable : BIHTAP.
# Useless variable : MIB_NETVV.
# Useless variable : BIHTAV.
# Useless variable : MIB_NETPP.
# Useless variable : MIB_NETVP.
# Useless variable : BIPTAP.
# Useless variable : MIB_NETCT.
# Useless variable : BICPF.
# Useless variable : BIN.
# Useless variable : RFCD.
# Useless variable : BNNSV.
# Useless variable : BNNAV.
# Useless variable : BNRV.
# Useless variable : BNNSP.
# Useless variable : BNNAP.
# Useless variable : BNRP.
# Useless variable : SPENETNPCT.
# Useless variable : SPETOTP.
# Useless variable : SPEABP.
# Useless variable : SPEABPP.
# Useless variable : SPEABNPP.
# Useless variable : SPENETNPP.
# Useless variable : SPETOTC.
# Useless variable : SPEABC.
# Useless variable : SPEABPC.
# Useless variable : SPEABNPC.
# Useless variable : SPENETNPC.
# Useless variable : SPETOTV.
# Useless variable : SPEABV.
# Useless variable : SPEABPV.
# Useless variable : SPEABNPV.
# Useless variable : SPENETNPV.
# Useless variable : SPENETNPF.
# Useless variable : BNNAAC.
# Useless variable : NOCEPIMPC.
# Useless variable : BNNAAP.
# Useless variable : NOCEPIMPP.
# Useless variable : BNNAAV.
# Useless variable : NOCEPIMPV.
# Useless variable : NOCEPIMP.
# Useless variable : DIDABNCNP.
# Useless variable : SPENETPP.
# Useless variable : SPENETPC.
# Useless variable : SPENETPV.
# Useless variable : SPENETCT.
# Useless variable : SPENETPF.
# Useless variable : BNNSC.
# Useless variable : BNNAC.
# Useless variable : BNRC.
# Useless variable : TOTDABNCNP.
# Useless variable : DEFBNCNPF.
# Useless variable : BNN.
# Useless variable : RFNTEO.
# Useless variable : DEFLOCNPF.
# Useless variable : NPLOCCGAV.
# Useless variable : NPLOCV.
# Useless variable : MIB_ABNPVLV.
# Useless variable : MIB_NETNPVLV.
# Useless variable : MIB_ABNPPLV.
# Useless variable : MIB_NETNPPLV.
# Useless variable : NPLOCNETTV.
# Useless variable : TOTDEFLOCNP.
# Useless variable : MIB_ABNPVLC.
# Useless variable : MIB_NETNPVLC.
# Useless variable : NPLOCC.
# Useless variable : MIB_ABNPPLC.
# Useless variable : MIB_NETNPPLC.
# Useless variable : NPLOCCGAC.
# Useless variable : NPLOCNETTC.
# Useless variable : MIB_ABNPPLP.
# Useless variable : MIB_NETNPPLP.
# Useless variable : MIB_ABNPVLP.
# Useless variable : MIB_NETNPVLP.
# Useless variable : NPLOCCGAPAC.
# Useless variable : NPLOCPAC.
# Useless variable : NPLOCNETTPAC.
# Useless variable : DNPLOCIMPU.
# Useless variable : NPLOCNETF.
# Useless variable : PLOCCGAV.
# Useless variable : PLOCV.
# Useless variable : PLOCNETV.
# Useless variable : PLOCC.
# Useless variable : PLOCCGAC.
# Useless variable : PLOCNETC.
# Useless variable : PLOCPAC.
# Useless variable : PLOCCGAPAC.
# Useless variable : PLOCNETPAC.
# Useless variable : PLOCNETF.
# Useless variable : DEDMIN4.
# Useless variable : TSBN4.
# Useless variable : 2TSN4.
# Useless variable : EXTS4.
# Useless variable : TPS104.
# Useless variable : DFN4.
# Useless variable : 10MINS4.
# Useless variable : 2PRBC.
# Useless variable : EXPRC.
# Useless variable : 2PRBV.
# Useless variable : EXPRV.
# Useless variable : 2PRB3.
# Useless variable : PRB3.
# Useless variable : EXPR3.
# Useless variable : PLR3.
# Useless variable : APB3.
# Useless variable : PRB4.
# Useless variable : 2PRB4.
# Useless variable : EXPR4.
# Useless variable : PLR4.
# Useless variable : IND_APB4.
# Useless variable : APB4.
# Useless variable : 2PRB2.
# Useless variable : EXPR2.
# Useless variable : IND_APB3.
# Useless variable : 2PRB1.
# Useless variable : EXPR1.
# Useless variable : 2TSN1.
# Useless variable : EXTS1.
# Useless variable : 2TSN3.
# Useless variable : TSBN3.
# Useless variable : EXTS3.
# Useless variable : TPS103.
# Useless variable : DFN3.
# Useless variable : DEDMIN3.
# Useless variable : 10MINS3.
# Useless variable : 2TSN2.
# Useless variable : EXTS2.
# Useless variable : ABPR4.
# Useless variable : ABPR3.
# Useless variable : APR3.
# Useless variable : APR4.
# Useless variable : FRDPROV4.
# Useless variable : FRDPROV3.
# Useless variable : FRD3.
# Useless variable : IND_10MIN_04.
# Useless variable : IND_MIN4.
# Useless variable : D10M4.
# Useless variable : ABTS1FJ.
# Useless variable : ABTS1FP.
# Useless variable : TSN1FP.
# Useless variable : ABTSRFJ.
# Useless variable : TSNRFJ.
# Useless variable : TSN1FJ.
# Useless variable : TSNT4.
# Useless variable : PRNN4.
# Useless variable : ABTSRDJ.
# Useless variable : TSNRDJ.
# Useless variable : 2TSNC.
# Useless variable : EXTSC.
# Useless variable : TSBC.
# Useless variable : ABTS3VK.
# Useless variable : ABTS1UT.
# Useless variable : ABTSRBJ.
# Useless variable : ABTSRBP.
# Useless variable : ABDOMDBJ.
# Useless variable : TSNDBJ.
# Useless variable : ABDOMEBJ.
# Useless variable : ABGL1C.
# Useless variable : ABGL2C.
# Useless variable : TSNGL2C.
# Useless variable : TSNRBP.
# Useless variable : TSNGL1C.
# Useless variable : TSNEBJ.
# Useless variable : TSN3VK.
# Useless variable : TSN1UT.
# Useless variable : TSNRBJ.
# Useless variable : IND_10MIN_03.
# Useless variable : IND_MIN3.
# Useless variable : D10M3.
# Useless variable : IND_103.
# Useless variable : FPT3.
# Useless variable : REP103.
# Useless variable : ABTS1EJ.
# Useless variable : ABTS1EP.
# Useless variable : ABTSREJ.
# Useless variable : ABTSREP.
# Useless variable : TSNREP.
# Useless variable : TSN1EP.
# Useless variable : TSNREJ.
# Useless variable : TSN1EJ.
# Useless variable : TSNT3.
# Useless variable : PRNN3.
# Useless variable : TSN3.
# Useless variable : TSNN3.
# Useless variable : 2TSNV.
# Useless variable : EXTSV.
# Useless variable : TSBV.
# Useless variable : ABTS3VJ.
# Useless variable : ABTS1TT.
# Useless variable : TSN1TT.
# Useless variable : ABTSRAJ.
# Useless variable : ABTSRAP.
# Useless variable : ABDOMDAJ.
# Useless variable : ABDOMEAJ.
# Useless variable : TSNEAJ.
# Useless variable : TSN3VJ.
# Useless variable : TSNDAJ.
# Useless variable : ABGL1V.
# Useless variable : TSNGL1V.
# Useless variable : TSNRAP.
# Useless variable : ABGL2V.
# Useless variable : TSNGL2V.
# Useless variable : TSNRAJ.
# Useless variable : ABTSRCJ.
# Useless variable : TSNRCJ.
# Useless variable : PRR4.
# Useless variable : PRN3.
# Useless variable : PRR3.
# Useless variable : BPTP4.
# Useless variable : BN1V.
# Useless variable : BN1P.
# Useless variable : BN1C.
# Useless variable : BN1.
# Useless variable : SPEPVPC.
# Useless variable : SPEPVPP.
# Useless variable : SPEPVNPP.
# Useless variable : SPEPVNPC.
# Useless variable : SPEPVPV.
# Useless variable : SPEPVNPV.
# Useless variable : SPEPV.
# Useless variable : MIB_P1AP.
# Useless variable : MIB_NP1AP.
# Useless variable : MIB_1AP.
# Useless variable : MIB_P1AV.
# Useless variable : MIB_NP1AV.
# Useless variable : MIB_1AV.
# Useless variable : MIB_P1AC.
# Useless variable : MIB_NP1AC.
# Useless variable : MIB_1AC.
# Useless variable : MIB_1AF.
# Useless variable : REVIBI12C.
# Useless variable : REVIBI12P.
# Useless variable : REVIBI12V.
# Useless variable : BI12F.
# Useless variable : BA1P.
# Useless variable : BA1V.
# Useless variable : BA1C.
# Useless variable : BA1.
# Useless variable : BTP3A.
# Useless variable : BTPSJ.
# Useless variable : BPTPSJ.
# Useless variable : BTP18.
# Useless variable : BPTP18.
# Useless variable : BTPVT.
# Useless variable : BPTPVT.
# Useless variable : BTP40.
# Useless variable : BPTP40.
# Useless variable : RCM2FA.
# Useless variable : BPTP24.
# Useless variable : BTP2.
# Useless variable : BPTP2.
# Useless variable : REVTP.
# Useless variable : GLN4C.
# Useless variable : GLN4V.
# Useless variable : 4BAQV.
# Useless variable : 4BAQP.
# Useless variable : 4BAQC.
# Useless variable : 4BAQTOT.
# Useless variable : BAHQTOTMAXN.
# Useless variable : 4BAQTOTNET.
# Useless variable : REV4.
# Useless variable : GLN1C.
# Useless variable : GLN1V.
# Useless variable : GLN1.
# Useless variable : TSNN2TS3.
# Useless variable : 2RV1.
# Useless variable : 2RV4.
# Useless variable : 2RV2.
# Useless variable : 2RV3.
# Useless variable : T2RV.
# Useless variable : GLN2C.
# Useless variable : GLN2V.
# Useless variable : GLN2.
# Useless variable : PRR23.
# Useless variable : PRR2Z3.
# Useless variable : PENF3.
# Useless variable : PRR24.
# Useless variable : TSNN2REMP3.
# Useless variable : PENALIM3.
# Useless variable : PENALIM4.
# Useless variable : RG.
# Useless variable : VARIPTEFP.
# Useless variable : VARIPTEFN.
# Useless variable : INDTEFF.
# Useless variable : T2TSNC.
# Useless variable : TEXTSC.
# Useless variable : TTSBC.
# Useless variable : T2PRBV.
# Useless variable : TEXPRV.
# Useless variable : T2PRB2.
# Useless variable : TEXPR2.
# Useless variable : T2PRB3.
# Useless variable : TPRB3.
# Useless variable : TEXPR3.
# Useless variable : TPLR3.
# Useless variable : TAPB3.
# Useless variable : T2PRBC.
# Useless variable : TEXPRC.
# Useless variable : TPRB4.
# Useless variable : T2PRB4.
# Useless variable : TEXPR4.
# Useless variable : TPLR4.
# Useless variable : TAPB4.
# Useless variable : TIND_APB4.
# Useless variable : T2PRB1.
# Useless variable : TEXPR1.
# Useless variable : TIND_APB3.
# Useless variable : TABDOMDBJ.
# Useless variable : TABDOMEBJ.
# Useless variable : TABGL1C.
# Useless variable : TGLN1C.
# Useless variable : T2TSNV.
# Useless variable : TEXTSV.
# Useless variable : TTSBV.
# Useless variable : TABDOMDAJ.
# Useless variable : TABDOMEAJ.
# Useless variable : TABGL1V.
# Useless variable : TGLN1V.
# Useless variable : TGLN1.
# Useless variable : REV1.
# Useless variable : TABGL2V.
# Useless variable : TGLN2V.
# Useless variable : TABGL2C.
# Useless variable : TGLN2C.
# Useless variable : TGLN2.
# Useless variable : REV2.
# Useless variable : TABGL3V.
# Useless variable : TTSNGL1V.
# Useless variable : TTSNEAJ.
# Useless variable : TTSNDAJ.
# Useless variable : TTSNGL3V.
# Useless variable : TTSNGL2V.
# Useless variable : TTSV.
# Useless variable : T2TSN1.
# Useless variable : TEXTS1.
# Useless variable : TDEDMIN4.
# Useless variable : TTSBN4.
# Useless variable : T2TSN4.
# Useless variable : TEXTS4.
# Useless variable : TTPS104.
# Useless variable : TDFN4.
# Useless variable : T10MINS4.
# Useless variable : T2TSN3.
# Useless variable : TTSBN3.
# Useless variable : TEXTS3.
# Useless variable : TDEDMIN3.
# Useless variable : TTPS103.
# Useless variable : TDFN3.
# Useless variable : T10MINS3.
# Useless variable : T2TSN2.
# Useless variable : TEXTS2.
# Useless variable : TABPR3.
# Useless variable : TAPR3.
# Useless variable : TABPR4.
# Useless variable : TAPR4.
# Useless variable : TFRDPROV4.
# Useless variable : TFRDPROV3.
# Useless variable : TPRNN4.
# Useless variable : TFRD3.
# Useless variable : TIND_10MIN_04.
# Useless variable : TIND_MIN4.
# Useless variable : TD10M4.
# Useless variable : TABTS1FJ.
# Useless variable : TTSN1FJ.
# Useless variable : TPRNN3.
# Useless variable : TIND_10MIN_03.
# Useless variable : TIND_MIN3.
# Useless variable : TD10M3.
# Useless variable : TIND_103.
# Useless variable : TFPT3.
# Useless variable : TREP103.
# Useless variable : TABTS1EJ.
# Useless variable : TABTS1EC.
# Useless variable : TABTS1EP.
# Useless variable : TTSN1EP.
# Useless variable : TTSN1EJ.
# Useless variable : TTSN1EC.
# Useless variable : TABTSREJ.
# Useless variable : TTSNREJ.
# Useless variable : TABTSREP.
# Useless variable : TTSNREP.
# Useless variable : TTSNT3.
# Useless variable : TTSN3.
# Useless variable : TTSNN3.
# Useless variable : TTSNN2TS3.
# Useless variable : TTSNEBJ.
# Useless variable : TABGL3C.
# Useless variable : TTSNGL3C.
# Useless variable : TTSNDBJ.
# Useless variable : TTSNGL2C.
# Useless variable : TTSNGL1C.
# Useless variable : TTSC.
# Useless variable : TTSNN2REMP3.
# Useless variable : TGLN3V.
# Useless variable : TGLN3C.
# Useless variable : TGLN3.
# Useless variable : REV3.
# Useless variable : TPRR4.
# Useless variable : TPRR24.
# Useless variable : TPENALIM4.
# Useless variable : TPRN3.
# Useless variable : TPRR3.
# Useless variable : TPRR23.
# Useless variable : TPRR2Z3.
# Useless variable : TPENF3.
# Useless variable : TPENALIM3.
# Useless variable : TOTALQUO.
# Useless variable : PERPBANC.
# Useless variable : PERPBICPNC.
# Useless variable : TPMIB_AVC.
# Useless variable : TPMIB_NETVC.
# Useless variable : TPMIB_APC.
# Useless variable : TPMIB_NETPC.
# Useless variable : PERPBICMNC.
# Useless variable : PERPBNCMNC.
# Useless variable : PERPBNCPNC.
# Useless variable : PERPNONSALC.
# Useless variable : PERPBANV.
# Useless variable : PERPBICPNV.
# Useless variable : PERPBNCPNV.
# Useless variable : TPMIB_AVV.
# Useless variable : TPMIB_NETVV.
# Useless variable : TPMIB_APV.
# Useless variable : TPMIB_NETPV.
# Useless variable : PERPBICMNV.
# Useless variable : PERPBNCMNV.
# Useless variable : PERPNONSALV.
# Useless variable : PERPPLATVANT.
# Useless variable : PERPPLATCANT.
# Useless variable : SOMDEFBNC.
# Useless variable : SOMDEFLOC.
# Useless variable : SOMDEFBIC.
# Useless variable : SOMDEFBASUP.
# Useless variable : SOMDEFANT.
# Useless variable : DFANTIMPU.
# Useless variable : RPREC.
# Useless variable : DFA.
# Useless variable : DEDIV.
# Useless variable : NUPROPT.
# Useless variable : RRBG.
# Useless variable : PERPBNCMNP.
# Useless variable : PERPBANP.
# Useless variable : PERPBNCPNP.
# Useless variable : TPMIB_AVP.
# Useless variable : TPMIB_NETVP.
# Useless variable : TPMIB_APP.
# Useless variable : TPMIB_NETPP.
# Useless variable : PERPBICMNP.
# Useless variable : PERPBICPNP.
# Useless variable : PERPNONSALP.
# Useless variable : PERPPLATPANT.
# Useless variable : NUREPAR.
# Useless variable : V_CR2.
# Useless variable : V_CNR2.
# Useless variable : RNG.
# Useless variable : NDA.
# Useless variable : ABTPA.
# Useless variable : RGRFR.
# Useless variable : RNGRFR.
# Useless variable : TMIB_TPRESP.
# Useless variable : TMIB_APP.
# Useless variable : TMIB_ABPP.
# Useless variable : TMIB_NETPP.
# Useless variable : TMIB_TPRESC.
# Useless variable : TMIB_APC.
# Useless variable : TMIB_ABPC.
# Useless variable : TMIB_NETPC.
# Useless variable : TMIB_TPRESV.
# Useless variable : TMIB_APV.
# Useless variable : TMIB_ABPV.
# Useless variable : TMIB_NETPV.
# Useless variable : TMIBNETPF.
# Useless variable : TMIB_TVENV.
# Useless variable : TMIB_AVV.
# Useless variable : TMIB_ABVV.
# Useless variable : TMIB_NETVV.
# Useless variable : TMIB_TVENC.
# Useless variable : TMIB_AVC.
# Useless variable : TMIB_ABVC.
# Useless variable : TMIB_NETVC.
# Useless variable : TMIB_TVENP.
# Useless variable : TMIB_AVP.
# Useless variable : TMIB_ABVP.
# Useless variable : TMIB_NETVP.
# Useless variable : TMIBNETVF.
# Useless variable : TBICPF.
# Useless variable : TTSPR4.
# Useless variable : TTSPR3.
# Useless variable : TMIB_ABNPVC.
# Useless variable : TMIB_NETNPVC.
# Useless variable : TMIB_ABNPVP.
# Useless variable : TMIB_NETNPVP.
# Useless variable : TMIB_ABNPVV.
# Useless variable : TMIB_NETNPVV.
# Useless variable : TMIBNETNPVF.
# Useless variable : TMIB_ABNPPC.
# Useless variable : TMIB_NETNPPC.
# Useless variable : TMIB_ABNPPV.
# Useless variable : TMIB_NETNPPV.
# Useless variable : TMIB_ABNPPP.
# Useless variable : TMIB_NETNPPP.
# Useless variable : TMIBNETNPPF.
# Useless variable : TBICNPF.
# Useless variable : TSPETOTP.
# Useless variable : TSPEABP.
# Useless variable : TSPEABPP.
# Useless variable : TSPEABNPP.
# Useless variable : TSPENETNPP.
# Useless variable : TSPETOTV.
# Useless variable : TSPEABV.
# Useless variable : TSPEABPV.
# Useless variable : TSPEABNPV.
# Useless variable : TSPENETNPV.
# Useless variable : TXSPEAAV.
# Useless variable : TXSPEHV.
# Useless variable : TXSPENETV.
# Useless variable : TXSPEAAP.
# Useless variable : TXSPEHP.
# Useless variable : TXSPENETP.
# Useless variable : TXSPEAAC.
# Useless variable : TXSPEHC.
# Useless variable : TXSPENETC.
# Useless variable : TXSPENET.
# Useless variable : TSPETOTC.
# Useless variable : TSPEABC.
# Useless variable : TSPEABPC.
# Useless variable : TSPEABNPC.
# Useless variable : TSPENETNPC.
# Useless variable : TSPENETPV.
# Useless variable : TSPENETPC.
# Useless variable : TSPENETPP.
# Useless variable : TBNN.
# Useless variable : TEFFREV.
# Useless variable : RRBGTEF.
# Useless variable : RNGTEF.
# Useless variable : ABTPATEF.
# Useless variable : TEFFREVINTER.
# Useless variable : TEFFREVTOT.
# Useless variable : TEFF.
# Useless variable : TEFFN_1.
# Useless variable : TEFFN_2.
# Useless variable : TEFFN.
# Useless variable : TOTALQUOHT.
# Useless variable : GLRWB.
# Useless variable : GLRWA.
# Useless variable : RPQPRRZ1.
# Useless variable : TGLRWB.
# Useless variable : TGLRWA.
# Useless variable : TRPQPRRZ1.
# Useless variable : TERPQPRRZ1.
# Useless variable : RPQTSV.
# Useless variable : TRPQTSV.
# Useless variable : TERPQTSV.
# Useless variable : TRPQPALIM2.
# Useless variable : RPQPALIM2.
# Useless variable : TERPQPALIM2.
# Useless variable : TRPQTSC.
# Useless variable : RPQTSC.
# Useless variable : TERPQTSC.
# Useless variable : TRPQPALIM3.
# Useless variable : RPQPALIM3.
# Useless variable : TERPQPALIM3.
# Useless variable : RPQTSREMP2.
# Useless variable : TRPQTSREMP2.
# Useless variable : TERPQTSREMP2.
# Useless variable : TRPQPRRZC.
# Useless variable : RPQPRRZC.
# Useless variable : TERPQPRRZC.
# Useless variable : TRPQRVO5.
# Useless variable : RPQRVO5.
# Useless variable : TERPQRVO5.
# Useless variable : RPQTSREMPC.
# Useless variable : TRPQTSREMPC.
# Useless variable : TERPQTSREMPC.
# Useless variable : RPQPRRC.
# Useless variable : TRPQPRRC.
# Useless variable : TERPQPRRC.
# Useless variable : TRPQRCMTS.
# Useless variable : RPQRCMTS.
# Useless variable : TERPQRCMTS.
# Useless variable : TEGLFC.
# Useless variable : TRPQRCMDC.
# Useless variable : RPQRCMDC.
# Useless variable : TERPQRCMDC.
# Useless variable : RPQPRR3.
# Useless variable : TRPQPRR3.
# Useless variable : TERPQPRR3.
# Useless variable : TRPQPRRZ3.
# Useless variable : RPQPRRZ3.
# Useless variable : TERPQPRRZ3.
# Useless variable : RPQRVO.
# Useless variable : TRPQRVO.
# Useless variable : TERPQRVO.
# Useless variable : RPQPRRZ4.
# Useless variable : TRPQPRRZ4.
# Useless variable : TERPQPRRZ4.
# Useless variable : RPQPALIM1.
# Useless variable : TRPQPALIM1.
# Useless variable : TERPQPALIM1.
# Useless variable : TEGLRF2.
# Useless variable : RPQPRRV.
# Useless variable : TRPQPRRV.
# Useless variable : TERPQPRRV.
# Useless variable : RPQPALIM4.
# Useless variable : TRPQPALIM4.
# Useless variable : TERPQPALIM4.
# Useless variable : TRPQTSREMP3.
# Useless variable : RPQTSREMP3.
# Useless variable : TERPQTSREMP3.
# Useless variable : TRPQPRRZV.
# Useless variable : RPQPRRZV.
# Useless variable : TERPQPRRZV.
# Useless variable : RPQPRRZ2.
# Useless variable : TRPQPRRZ2.
# Useless variable : TERPQPRRZ2.
# Useless variable : TRPQTS3.
# Useless variable : RPQTS3.
# Useless variable : TERPQTS3.
# Useless variable : TEGLF4.
# Useless variable : TRPQRVO6.
# Useless variable : RPQRVO6.
# Useless variable : TERPQRVO6.
# Useless variable : RPQRVO7.
# Useless variable : TRPQRVO7.
# Useless variable : TERPQRVO7.
# Useless variable : RPQTSREMPV.
# Useless variable : TRPQTSREMPV.
# Useless variable : TERPQTSREMPV.
# Useless variable : TRPQTS2.
# Useless variable : RPQTS2.
# Useless variable : TERPQTS2.
# Useless variable : TEGLF1.
# Useless variable : TEGLFV.
# Useless variable : TRPQTS4.
# Useless variable : RPQTS4.
# Useless variable : TERPQTS4.
# Useless variable : RPQPRR2.
# Useless variable : TRPQPRR2.
# Useless variable : TERPQPRR2.
# Useless variable : TRPQTS1.
# Useless variable : RPQTS1.
# Useless variable : TERPQTS1.
# Useless variable : TEGLF3.
# Useless variable : RPQPRR1.
# Useless variable : TRPQPRR1.
# Useless variable : TERPQPRR1.
# Useless variable : RPQRF1.
# Useless variable : TRPQRF1.
# Useless variable : TERPQRF1.
# Useless variable : RPQRCMGO.
# Useless variable : TRPQRCMGO.
# Useless variable : TERPQRCMGO.
# Useless variable : TRPQRCMTR.
# Useless variable : RPQRCMTR.
# Useless variable : TERPQRCMTR.
# Useless variable : TRPQTSREMP4.
# Useless variable : RPQTSREMP4.
# Useless variable : TERPQTSREMP4.
# Useless variable : TRPQPALIMV.
# Useless variable : RPQPALIMV.
# Useless variable : TERPQPALIMV.
# Useless variable : TRPQPALIMC.
# Useless variable : RPQPALIMC.
# Useless variable : TERPQPALIMC.
# Useless variable : TEGL1.
# Useless variable : TRPQRCMFU.
# Useless variable : RPQRCMFU.
# Useless variable : TERPQRCMFU.
# Useless variable : RPQTSREMP1.
# Useless variable : TRPQTSREMP1.
# Useless variable : TERPQTSREMP1.
# Useless variable : TEGLF2.
# Useless variable : TEGL2.
# Useless variable : RPQPRR4.
# Useless variable : TRPQPRR4.
# Useless variable : TERPQPRR4.
# Useless variable : TEGL3.
# Useless variable : TRPQRCMCH.
# Useless variable : RPQRCMCH.
# Useless variable : TERPQRCMCH.
# Useless variable : PVTXEFF.
# Useless variable : TEFFREVRFR.
# Useless variable : RRBGTEFRFR.
# Useless variable : RNGTEFRFR.
# Useless variable : ABTPATEFRFR.
# Useless variable : TEFFREVTOTRFR.
# Useless variable : XBIPP.
# Useless variable : XBNC.
# Useless variable : XBAP.
# Useless variable : XBIPC.
# Useless variable : XBNNPP.
# Useless variable : XBAC.
# Useless variable : XTSBC.
# Useless variable : XEXTSC.
# Useless variable : XETSNNC.
# Useless variable : XBNV.
# Useless variable : TRCMRTNC.
# Useless variable : TRCMRABD.
# Useless variable : XBAV.
# Useless variable : XBIPV.
# Useless variable : XTSBV.
# Useless variable : XEXTSV.
# Useless variable : XETSNNV.
# Useless variable : XTSNNV.
# Useless variable : XBINPV.
# Useless variable : XBINPP.
# Useless variable : XBNNPC.
# Useless variable : XTSNNC.
# Useless variable : XBNP.
# Useless variable : PVTAUX.
# Useless variable : XEXOCETC.
# Useless variable : XBINPC.
# Useless variable : XACCESS.
# Useless variable : XBNNPV.
# Useless variable : XFORFAIT.
# Useless variable : XEXOCETV.
# Useless variable : DFANT.
# Useless variable : DAR_REP.
# Useless variable : SOMDEFICITHTS.
# Useless variable : REVKIRE.
# Useless variable : DRTNC.
# Useless variable : TOTDEFLOCNPBIS.
# Useless variable : NPLOCSP.
# Useless variable : NPLOCCGASP.
# Useless variable : MIBNETNPVLSP.
# Useless variable : NPLOCNETTSP.
# Useless variable : NPLOCSV.
# Useless variable : NPLOCCGASV.
# Useless variable : MIBNETNPVLSV.
# Useless variable : NPLOCNETTSV.
# Useless variable : NPLOCSC.
# Useless variable : MIBNETNPVLSC.
# Useless variable : NPLOCCGASC.
# Useless variable : NPLOCNETTSC.
# Useless variable : NPLOCNETSF.
# Useless variable : RDNP.
# Useless variable : PVTAUXPS.
# Useless variable : RDNCP.
# Useless variable : RDPTP.
# Useless variable : RGLOA.
# Useless variable : REI.
# Useless variable : AUBAINE13A.
# Useless variable : AVPLAF13A.
# Useless variable : AUBAINE13B.
# Useless variable : AVPLAF13B.
# Useless variable : AVPLAF13.
# Useless variable : VARRMOND.
# Useless variable : VARDMOND.
# Useless variable : GLRWBM.
# Useless variable : GLRWAM.
# Useless variable : RPQPALIMCM.
# Useless variable : RPQPRRZ2M.
# Useless variable : RPQTSREMP3M.
# Useless variable : RPQPALIM3M.
# Useless variable : RPQPALIM2M.
# Useless variable : RPQTSREMP1M.
# Useless variable : RPQF1M.
# Useless variable : RPQFCM.
# Useless variable : RPQRF2M.
# Useless variable : RPQRCMDCM.
# Useless variable : RPQTS3M.
# Useless variable : RPQPRRZ4M.
# Useless variable : RPQTSREMPCM.
# Useless variable : RPQRCMTRM.
# Useless variable : RPQF3M.
# Useless variable : RPQPRRZVM.
# Useless variable : RPQRVOM.
# Useless variable : RPQF2M.
# Useless variable : RPQPRR1M.
# Useless variable : RPQRWBM.
# Useless variable : RPQPRR3M.
# Useless variable : RPQTSCM.
# Useless variable : RPQPRRZ3M.
# Useless variable : RPQPRRZ1M.
# Useless variable : RPQPRR4M.
# Useless variable : RPQTSREMPVM.
# Useless variable : RPQPALIMVM.
# Useless variable : RPQRVO6M.
# Useless variable : RPQRCMCHM.
# Useless variable : RPQF4M.
# Useless variable : RPQPRRCM.
# Useless variable : RPQTSREMP2M.
# Useless variable : RPQPRRVM.
# Useless variable : RPQRCMTSM.
# Useless variable : RPQPRRZCM.
# Useless variable : RPQRF1M.
# Useless variable : RPQTSVM.
# Useless variable : RPQTS2M.
# Useless variable : RPQTSREMP4M.
# Useless variable : RPQPALIM1M.
# Useless variable : RPQRCMFUM.
# Useless variable : RPQFVM.
# Useless variable : RPQPALIM4M.
# Useless variable : RPQRVO7M.
# Useless variable : RPQRCMGOM.
# Useless variable : RPQPRR2M.
# Useless variable : RPQRVO5M.
# Useless variable : RPQTS1M.
# Useless variable : RPQRVGM.
# Useless variable : RPQTS4M.
# Useless variable : RPQRWAM.
# Useless variable : RPQFC.
# Useless variable : RPQF3.
# Useless variable : RPQF4.
# Useless variable : RPQRVG.
# Useless variable : RPQRF2.
# Useless variable : RPQF1.
# Useless variable : RPQF2.
# Useless variable : RPQFV.
# Useless variable : RPQRWA.
# Useless variable : RPQRWB.
# Useless variable : AUBAINE12.
# Useless variable : AVPLAF12.
# Useless variable : AUBAINE11.
# Useless variable : AVPLAF11.
# Useless variable : AUBAINE10.
# Useless variable : AVPLAF10.
# Useless variable : AUBAINE9.
# Useless variable : AVPLAF9.
# Useless variable : AVFISCOPTER.
# Useless variable : V_EAD.
# Useless variable : V_EAG.
# Useless variable : BPTP3.
# Useless variable : DOMITPG.
# Useless variable : DOMAVTD.
# Useless variable : DOMAVTG.
# Useless variable : DOMAVTO.
# Useless variable : VAR0BT.
# Useless variable : NB0BTMIQAR.
# Useless variable : NB0BT2MIQAR.
# Useless variable : NB0BTQAR.
# Useless variable : NBMIQAR.
# Useless variable : PLAQAR.
# Useless variable : PLAFCDPART.
# Useless variable : BOOL_V.
# Useless variable : SFCD2.
# Useless variable : SFV1.

# %% [markdown]
# ## Graph study

# %%
len(formulas_simple)
# Out:
# 2684

# %%
var = computing_order_simple[100]
print(var + json.dumps(formulas_simple[var], indent=4))
# Out:
# TTSN1TT{
#     "nodetype": "call",
#     "name": "-",
#     "args": [
#         {
#             "nodetype": "symbol",
#             "name": "TABTS1TT"
#         }
#     ]
# }

# %%
formulas_simple['TABTS1TT']
# Out:
# {'args': [{'nodetype': 'float', 'value': 0.0},
#   {'args': [{'name': 'TREP10V', 'nodetype': 'symbol'},
#     {'args': [{'name': 'TABTS1AJ', 'nodetype': 'symbol'}],
#      'name': '-',
#      'nodetype': 'call'},
#     {'args': [{'name': 'TABTS1AC', 'nodetype': 'symbol'}],
#      'name': '-',
#      'nodetype': 'call'},
#     {'args': [{'name': 'TABTS1AP', 'nodetype': 'symbol'}],
#      'name': '-',
#      'nodetype': 'call'},
#     {'args': [{'name': 'TABTS3VJ', 'nodetype': 'symbol'}],
#      'name': '-',
#      'nodetype': 'call'}],
#    'name': '+',
#    'nodetype': 'call'}],
#  'name': 'max',
#  'nodetype': 'call'}

# %%
formulas_simple['TREP10V']
# Out:
# {'args': [{'args': [{'name': 'TIND_10V', 'nodetype': 'symbol'},
#     {'name': 'TD10MV', 'nodetype': 'symbol'}],
#    'name': '*',
#    'nodetype': 'call'},
#   {'args': [{'args': [{'nodetype': 'float', 'value': 1.0},
#       {'args': [{'name': 'TIND_10V', 'nodetype': 'symbol'}],
#        'name': '-',
#        'nodetype': 'call'}],
#      'name': '+',
#      'nodetype': 'call'},
#     {'name': 'TFPTV', 'nodetype': 'symbol'}],
#    'name': '*',
#    'nodetype': 'call'}],
#  'name': '+',
#  'nodetype': 'call'}

# %%
formulas_simple['TIND_10V']
# Out:
# {'args': [{'args': [{'name': 'T10MINSV', 'nodetype': 'symbol'},
#     {'args': [{'name': 'TFRDV', 'nodetype': 'symbol'}],
#      'name': '-',
#      'nodetype': 'call'}],
#    'name': '+',
#    'nodetype': 'call'}],
#  'name': 'positif_ou_nul',
#  'nodetype': 'call'}

# %%
formulas_simple['T10MINSV']
# Out:
# {'args': [{'args': [{'name': 'TTSBNV', 'nodetype': 'symbol'},
#     {'name': 'TDEDMINV', 'nodetype': 'symbol'}],
#    'name': 'min',
#    'nodetype': 'call'},
#   {'name': 'TDFNV', 'nodetype': 'symbol'}],
#  'name': 'max',
#  'nodetype': 'call'}

# %%
formulas_simple['TTSBNV']
# Out:
# {'args': [{'name': 'TSHALLOV', 'nodetype': 'symbol'},
#   {'name': 'ALLOV', 'nodetype': 'symbol'}],
#  'name': '+',
#  'nodetype': 'call'}

# %%
def get_children(node):
    nodetype = node['nodetype']

    if nodetype == 'symbol':
        name = node['name']
        return set([name])
        
    elif nodetype == 'float':
        return set()
    
    elif nodetype == 'call':
        args = node['args']
        children = set()
        for arg in args:
            children = children | get_children(arg)

        return children
        
    raise ValueError('Unknown type : %s'%nodetype)

# %%
children_dict_simple = {}
for name, formula in formulas_simple.items():
    children_dict_simple[name] = get_children(formula)

# %%
# IDRS3, REVKIRE are already computed
to_inspect = ['NBPT', 'BCSG', 'BRDS', 'IBM23', 'TXMOYIMP', 'NAPTIR', 'IINET', 'RRRBG', 'RNI', 'IAVIM']
dependencies_formulas = []
dependencies_inputs = []

while to_inspect:
    node = to_inspect.pop()
    
    if node in dependencies_formulas:
        continue
     
    for child in children_dict_simple[node]:
        if child in formulas_simple:
            if (child not in dependencies_formulas) and (child not in to_inspect):
                to_inspect.append(child)
        elif child in inputs_simple:
            if child not in dependencies_inputs:
                dependencies_inputs.append(child)
        else:
            raise Exception('Unknown variable category : %s for parent %s.'%(child, node))

    dependencies_formulas.append(node)

# %%
len(dependencies_formulas)
# Out:
# 1658

# %% [markdown]
# ## Ignore unused formulas

# %%
new_computing_order = []
for var in computing_order_simple:
    if var in dependencies_formulas:
        new_computing_order.append(var)
computing_order_simple = new_computing_order
formulas_simple = {var: formulas_simple[var] for var in dependencies_formulas}

# %%
with open('../json/formulas_simple.json', 'w') as f:
    f.write(json.dumps(formulas_simple)) 
with open('../json/computing_order_simple.json', 'w') as f:
    f.write(json.dumps(computing_order_simple)) 
with open('../json/inputs_simple.json', 'w') as f:
    f.write(json.dumps(inputs_simple))

# %% [markdown]
# ## Test it

# %%
import compute_simple
import function_set_np

# %%
alias_values = {'1AJ': 30000.}
input_values = compute_simple.prepare(alias_values)

# %%
compute_simple.compute(input_values)
# Out:
# array([ 2461.,  2461.,  2461.,  2461.,  2461.,  2461.,  2461.,  2461.,
#         2461.,  2461.])
